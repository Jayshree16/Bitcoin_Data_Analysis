# %% [markdown]
# ### Lets Read data & Perform basic basic analysis !

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:/Users/JAYSHREE/Desktop/python project analyst/bitcoin_price_Training - Training.csv')
df['Date']= df['Date'].astype('datetime64[ns]')
df.sort_values(by = "Date")
data = df.sort_index(ascending=False).reset_index()
data.drop('index' , axis = 1, inplace = True)
bitcoin_sample = data[0:50]

# %%
df = pd.read_csv(r'C:/Users/JAYSHREE/Desktop/python project analyst/bitcoin_price_Training - Training.csv')

# %%
df.head(3)
# Out:
#            Date     Open     High      Low    Close       Volume  \
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34  860,575,000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18  705,943,000
# 2  Jul 29, 2017  2807.02  2808.76  2692.80  2726.45  803,746,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1556 non-null   object
#  1   Open        1556 non-null   float64
#  2   High        1556 non-null   float64
#  3   Low         1556 non-null   float64
#  4   Close       1556 non-null   float64
#  5   Volume      1556 non-null   object
#  6   Market Cap  1556 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 85.2+ KB

# %%
df.describe().T
# Out:
#         count        mean         std    min       25%      50%       75%  \
# Open   1556.0  582.625328  523.137312  68.50  254.2875  438.600  662.4375
# High   1556.0  597.992847  542.992855  74.56  260.3275  447.560  674.5250
# Low    1556.0  567.851446  505.877401  65.53  248.8350  430.570  646.7350
# Close  1556.0  584.239396  525.904442  68.43  254.3200  438.855  663.4025
#
#            max
# Open   2953.22
# High   2999.91
# Low    2840.53
# Close  2958.11

# %% [markdown]
# ### Data Pre-Processing

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
df['Date']= df['Date'].astype('datetime64[ns]')

##pd.to_datetime()

# %%
df.sort_values(by = "Date")
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 1555 2013-04-28   135.30   135.98   132.10   134.21              -
# 1554 2013-04-29   134.44   147.49   134.00   144.54              -
# 1553 2013-04-30   144.00   146.93   134.05   139.00              -
# 1552 2013-05-01   139.00   139.89   107.72   116.99              -
# 1551 2013-05-02   116.38   125.60    92.28   105.21              -
# ...         ...      ...      ...      ...      ...            ...
# 4    2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 3    2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 2    2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1    2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 0    2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 1555   1,500,520,000
# 1554   1,491,160,000
# 1553   1,597,780,000
# 1552   1,542,820,000
# 1551   1,292,190,000
# ...              ...
# 4     41,816,500,000
# 3     44,144,400,000
# 2     46,246,700,000
# 1     44,890,700,000
# 0     45,535,800,000
#
# [1556 rows x 7 columns]

# %%
df['Date']
# Out:
# 0      2017-07-31
# 1      2017-07-30
# 2      2017-07-29
# 3      2017-07-28
# 4      2017-07-27
#           ...
# 1551   2013-05-02
# 1552   2013-05-01
# 1553   2013-04-30
# 1554   2013-04-29
# 1555   2013-04-28
# Name: Date, Length: 1556, dtype: datetime64[ns]

# %%
df['Date'].min()
# Out:
# Timestamp('2013-04-28 00:00:00')

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
data = df.sort_index(ascending=False).reset_index()

# %%
data.drop('index' , axis = 1, inplace = True)

# %%
data
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0    2013-04-28   135.30   135.98   132.10   134.21              -
# 1    2013-04-29   134.44   147.49   134.00   144.54              -
# 2    2013-04-30   144.00   146.93   134.05   139.00              -
# 3    2013-05-01   139.00   139.89   107.72   116.99              -
# 4    2013-05-02   116.38   125.60    92.28   105.21              -
# ...         ...      ...      ...      ...      ...            ...
# 1551 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 1552 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 1553 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1554 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 1555 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 0      1,500,520,000
# 1      1,491,160,000
# 2      1,597,780,000
# 3      1,542,820,000
# 4      1,292,190,000
# ...              ...
# 1551  41,816,500,000
# 1552  44,144,400,000
# 1553  46,246,700,000
# 1554  44,890,700,000
# 1555  45,535,800,000
#
# [1556 rows x 7 columns]

# %% [markdown]
# ### What was the change in price of the stock overtime?

# %%
plt.figure(figsize=(20,12))

for index, col in enumerate(['Open', 'High', 'Low', 'Close'], 1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'] , df[col])
    plt.title(col)

# %% [markdown]
# ### Analysing open, high, low, close value of Bitcoin

# %%
data.shape
# Out:
# (1556, 7)

# %%
bitcoin_sample = data[0:50]

# %%
bitcoin_sample
# Out:
#          Date    Open    High     Low   Close Volume     Market Cap
# 0  2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000
# 1  2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000
# 2  2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000
# 3  2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000
# 4  2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000
# 5  2013-05-03  106.25  108.13   79.10   97.75      -  1,180,070,000
# 6  2013-05-04   98.10  115.00   92.50  112.50      -  1,089,890,000
# 7  2013-05-05  112.90  118.80  107.14  115.91      -  1,254,760,000
# 8  2013-05-06  115.98  124.66  106.64  112.30      -  1,289,470,000
# 9  2013-05-07  112.25  113.44   97.70  111.50      -  1,248,470,000
# 10 2013-05-08  109.60  115.78  109.60  113.57      -  1,219,450,000
# 11 2013-05-09  113.20  113.46  109.26  112.67      -  1,259,980,000
# 12 2013-05-10  112.80  122.00  111.55  117.20      -  1,255,970,000
# 13 2013-05-11  117.70  118.68  113.01  115.24      -  1,311,050,000
# 14 2013-05-12  115.64  117.45  113.44  115.00      -  1,288,630,000
# 15 2013-05-13  114.82  118.70  114.50  117.98      -  1,279,980,000
# 16 2013-05-14  117.98  119.80  110.25  111.50      -  1,315,720,000
# 17 2013-05-15  111.40  115.81  103.50  114.22      -  1,242,760,000
# 18 2013-05-16  114.22  118.76  112.20  118.76      -  1,274,620,000
# 19 2013-05-17  118.21  125.30  116.57  123.02      -  1,319,590,000
# 20 2013-05-18  123.50  125.25  122.30  123.50      -  1,379,140,000
# 21 2013-05-19  123.21  124.50  119.57  121.99      -  1,376,370,000
# 22 2013-05-20  122.50  123.62  120.12  122.00      -  1,368,910,000
# 23 2013-05-21  122.02  123.00  121.21  122.88      -  1,363,940,000
# 24 2013-05-22  122.89  124.00  122.00  123.89      -  1,374,130,000
# 25 2013-05-23  123.80  126.93  123.10  126.70      -  1,384,780,000
# 26 2013-05-24  126.30  133.85  125.72  133.20      -  1,413,300,000
# 27 2013-05-25  133.10  133.22  128.90  131.98      -  1,489,950,000
# 28 2013-05-26  131.99  136.00  130.62  133.48      -  1,478,030,000
# 29 2013-05-27  133.50  135.47  124.70  129.75      -  1,495,520,000
# 30 2013-05-28  129.77  130.58  125.60  129.00      -  1,454,310,000
# 31 2013-05-29  129.00  132.59  127.66  132.30      -  1,446,190,000
# 32 2013-05-30  132.25  132.25  127.00  128.80      -  1,483,180,000
# 33 2013-05-31  128.80  129.90  126.40  129.00      -  1,445,050,000
# 34 2013-06-01  128.81  129.78  127.20  129.30      -  1,445,800,000
# 35 2013-06-02  129.30  129.40  115.05  122.29      -  1,451,930,000
# 36 2013-06-03  122.50  122.50  116.00  122.22      -  1,376,180,000
# 37 2013-06-04  120.74  123.84  119.10  121.42      -  1,357,020,000
# 38 2013-06-05  121.40  123.47  119.90  121.65      -  1,365,110,000
# 39 2013-06-06  121.90  123.10  117.25  118.00      -  1,371,300,000
# 40 2013-06-07  118.97  119.00  106.42  111.50      -  1,338,880,000
# 41 2013-06-08  111.00  111.42  107.30  108.30      -  1,249,630,000
# 42 2013-06-09  107.89  108.99   88.50  100.00      -  1,215,130,000
# 43 2013-06-10  100.44  110.10   95.00  106.35      -  1,131,570,000
# 44 2013-06-11  106.35  109.60  104.00  108.90      -  1,198,640,000
# 45 2013-06-12  109.00  111.79  106.73  108.15      -  1,229,000,000
# 46 2013-06-13  108.78  110.30  100.53  104.00      -  1,227,030,000
# 47 2013-06-14  103.95  104.70   98.00   99.98      -  1,173,060,000
# 48 2013-06-15  100.00  103.70   98.00   99.99      -  1,128,950,000
# 49 2013-06-16   99.80  101.60   98.95   99.51      -  1,127,120,000

# %%
# !pip install chart_studio
# !pip install plotly
# Out:
# Requirement already satisfied: chart_studio in c:\users\jayshree\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: plotly in c:\users\jayshree\anaconda3\lib\site-packages (from chart_studio) (5.24.1)
# Requirement already satisfied: requests in c:\users\jayshree\anaconda3\lib\site-packages (from chart_studio) (2.32.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\jayshree\anaconda3\lib\site-packages (from chart_studio) (1.4.2)
# Requirement already satisfied: six in c:\users\jayshree\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jayshree\anaconda3\lib\site-packages (from plotly->chart_studio) (8.2.3)
# Requirement already satisfied: packaging in c:\users\jayshree\anaconda3\lib\site-packages (from plotly->chart_studio) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayshree\anaconda3\lib\site-packages (from requests->chart_studio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayshree\anaconda3\lib\site-packages (from requests->chart_studio) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayshree\anaconda3\lib\site-packages (from requests->chart_studio) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayshree\anaconda3\lib\site-packages (from requests->chart_studio) (2024.8.30)
# Requirement already satisfied: plotly in c:\users\jayshree\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jayshree\anaconda3\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\jayshree\anaconda3\lib\site-packages (from plotly) (24.1)

# %%
import chart_studio.plotly as py

import plotly.graph_objs as go

import plotly.express as px

from plotly.offline import download_plotlyjs, init_notebook_mode , plot , iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Candlestick
             (x=bitcoin_sample['Date'],
              high = bitcoin_sample['High'],
              open = bitcoin_sample['Open'],
              close = bitcoin_sample['Close'],
              low = bitcoin_sample['Low'])

# %%
candle_data = [trace]
# fig = go.Figure(data=[trace])
# fig.update_layout(
#     height=700,   # adjust number (e.g., 600, 800, etc.)
#     title="Bitcoin Candlestick Chart"
# )

layout = {
    'title': 'Bitcoin Historical Prices',
    'xaxis':{'title':'Date'}
}

# %%
fig = go.Figure(data = candle_data, layout=layout)

fig.update_layout(xaxis_rangeslider_visible = False)
fig.show()

# %% [markdown]
# ### Analysing closing price

# %%
data['Close'].plot()
# Out:
# <Axes: >

# %%
data['Close']
# Out:
# 0        134.21
# 1        144.54
# 2        139.00
# 3        116.99
# 4        105.21
#          ...
# 1551    2671.78
# 1552    2809.01
# 1553    2726.45
# 1554    2757.18
# 1555    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data.set_index('Date', inplace=True)

# %%
data.Close
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,2,1)
data['Close'].plot()
plt.title('No Scaling')

plt.subplot(1,2,2)
np.log1p(data['Close']).plot()
plt.title('Log Scaling')
plt.yscale('log')

# %% [markdown]
# ### Analyse closing Price on Yearly, Quarterly, monthly basis

# %%
data.head(2)
# Out:
#               Open    High    Low   Close Volume     Market Cap
# Date
# 2013-04-28  135.30  135.98  132.1  134.21      -  1,500,520,000
# 2013-04-29  134.44  147.49  134.0  144.54      -  1,491,160,000

# %%
data['Close'].resample('YE').mean()
# Out:
# Date
# 2013-12-31     257.474476
# 2014-12-31     527.236658
# 2015-12-31     272.453260
# 2016-12-31     568.492131
# 2017-12-31    1628.622123
# Freq: YE-DEC, Name: Close, dtype: float64

# %%
data['Close'].resample('YE').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data['Close'].resample('QE').mean()
# Out:
# Date
# 2013-06-30     115.162188
# 2013-09-30     111.291196
# 2013-12-31     502.657609
# 2014-03-31     700.586000
# 2014-06-30     520.929341
# 2014-09-30     534.055435
# 2014-12-31     357.075761
# 2015-03-31     251.209333
# 2015-06-30     236.858022
# 2015-09-30     254.859891
# 2015-12-31     346.037065
# 2016-03-31     410.728571
# 2016-06-30     512.492747
# 2016-09-30     615.702283
# 2016-12-31     732.721413
# 2017-03-31    1034.707444
# 2017-06-30    1912.552198
# 2017-09-30    2519.418387
# Freq: QE-DEC, Name: Close, dtype: float64

# %%
data['Close'].resample('QE').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data['Close'].resample('m').mean()
# Out:
# C:\Users\JAYSHREE\AppData\Local\Temp\ipykernel_24168\2873602972.py:1: FutureWarning:
#
# 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
# Date
# 2013-04-30     139.250000
# 2013-05-31     119.993226
# 2013-06-30     107.761333
# 2013-07-31      90.512258
# 2013-08-31     113.905161
# 2013-09-30     130.061667
# 2013-10-31     158.311935
# 2013-11-30     550.420667
# 2013-12-31     800.780968
# 2014-01-31     844.168387
# 2014-02-28     661.618214
# 2014-03-31     592.200323
# 2014-04-30     461.362000
# 2014-05-31     486.651290
# 2014-06-30     615.917333
# 2014-07-31     618.025484
# 2014-08-31     536.087742
# 2014-09-30     445.186333
# 2014-10-31     364.150000
# 2014-11-30     366.100000
# 2014-12-31     341.268387
# 2015-01-31     248.782581
# 2015-02-28     234.153571
# 2015-03-31     269.041290
# 2015-04-30     235.491667
# 2015-05-31     236.996774
# 2015-06-30     238.081000
# 2015-07-31     279.563871
# 2015-08-31     250.734516
# 2015-09-30     233.595333
# 2015-10-31     264.855161
# 2015-11-30     348.883333
# 2015-12-31     424.464516
# 2016-01-31     410.844516
# 2016-02-29     404.408276
# 2016-03-31     416.525161
# 2016-04-30     434.339333
# 2016-05-31     461.953871
# 2016-06-30     642.869667
# 2016-07-31     661.355484
# 2016-08-31     579.585161
# 2016-09-30     605.848333
# 2016-10-31     643.550000
# 2016-11-30     726.349000
# 2016-12-31     828.059677
# 2017-01-31     914.916452
# 2017-02-28    1062.533214
# 2017-03-31    1129.365484
# 2017-04-30    1206.641000
# 2017-05-31    1895.383548
# 2017-06-30    2636.204333
# 2017-07-31    2519.418387
# Freq: ME, Name: Close, dtype: float64

# %%
data['Close'].resample('ME').mean()
# Out:
# Date
# 2013-04-30     139.250000
# 2013-05-31     119.993226
# 2013-06-30     107.761333
# 2013-07-31      90.512258
# 2013-08-31     113.905161
# 2013-09-30     130.061667
# 2013-10-31     158.311935
# 2013-11-30     550.420667
# 2013-12-31     800.780968
# 2014-01-31     844.168387
# 2014-02-28     661.618214
# 2014-03-31     592.200323
# 2014-04-30     461.362000
# 2014-05-31     486.651290
# 2014-06-30     615.917333
# 2014-07-31     618.025484
# 2014-08-31     536.087742
# 2014-09-30     445.186333
# 2014-10-31     364.150000
# 2014-11-30     366.100000
# 2014-12-31     341.268387
# 2015-01-31     248.782581
# 2015-02-28     234.153571
# 2015-03-31     269.041290
# 2015-04-30     235.491667
# 2015-05-31     236.996774
# 2015-06-30     238.081000
# 2015-07-31     279.563871
# 2015-08-31     250.734516
# 2015-09-30     233.595333
# 2015-10-31     264.855161
# 2015-11-30     348.883333
# 2015-12-31     424.464516
# 2016-01-31     410.844516
# 2016-02-29     404.408276
# 2016-03-31     416.525161
# 2016-04-30     434.339333
# 2016-05-31     461.953871
# 2016-06-30     642.869667
# 2016-07-31     661.355484
# 2016-08-31     579.585161
# 2016-09-30     605.848333
# 2016-10-31     643.550000
# 2016-11-30     726.349000
# 2016-12-31     828.059677
# 2017-01-31     914.916452
# 2017-02-28    1062.533214
# 2017-03-31    1129.365484
# 2017-04-30    1206.641000
# 2017-05-31    1895.383548
# 2017-06-30    2636.204333
# 2017-07-31    2519.418387
# Freq: ME, Name: Close, dtype: float64

# %%
data['Close'].resample('ME').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Analysing Daily Change in Closing Price of Stocks

# %%
data['Close']
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close_price_pct_change']= data['Close'].pct_change()*100

# %%
data['Close_price_pct_change']
# Out:
# Date
# 2013-04-28          NaN
# 2013-04-29     7.696893
# 2013-04-30    -3.832849
# 2013-05-01   -15.834532
# 2013-05-02   -10.069237
#                 ...
# 2017-07-27     5.626915
# 2017-07-28     5.136276
# 2017-07-29    -2.939114
# 2017-07-30     1.127107
# 2017-07-31     4.285538
# Name: Close_price_pct_change, Length: 1556, dtype: float64

# %%
data['Close_price_pct_change'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import chart_studio.plotly as py

import plotly.graph_objs as go

import plotly.express as px

from plotly.offline import download_plotlyjs, init_notebook_mode , plot , iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data['Close_price_pct_change'].iplot()
# Out:
# C:\Users\JAYSHREE\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
